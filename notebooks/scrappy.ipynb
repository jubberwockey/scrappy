# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from src.scrappy import Scrappy
from src.config import ScrapingConfig

pd.options.display.max_columns = 50
pd.options.display.max_rows = 50
pd.set_option('future.no_silent_downcasting', True)

s = Scrappy(
        funds_overview_path='data/funds_overview.csv',
        performance_path='data/performance.csv',
        timeseries_path='data/timeseries.csv'
    )

benchmarks = ScrapingConfig.DEFAULT_BENCHMARKS
# Out:
# INFO:src.scrappy:Loaded funds_overview data from data/funds_overview.csv
# INFO:src.scrappy:Loaded performance data from data/performance.csv
# INFO:src.scrappy:Loaded timeseries data from data/timeseries.csv

# %%
s.download_funds_overview(benchmark=True)
s.download_funds_overview(limit=15000, etf=False, option_str='morningstar_sustainability_rating=5')
s.download_funds_overview(limit=6000, etf=True, option_str='morningstar_sustainability_rating=5')
s.download_funds_overview(limit=8000, filter_ids='renten', etf=False)
s.download_funds_overview(limit=3000, filter_ids='renten', etf=True)
s.download_funds_overview(limit=3000, filter_ids='esg', etf=False)
s.download_funds_overview(limit=1000, filter_ids='esg', etf=True)

s.extract_performance()

s.save_funds_overview('data/funds_overview.csv')
s.save_performance('data/performance.csv')
# Out:
# INFO:src.scrappy:Successfully downloaded 55 funds (category: benchmark)
# INFO:src.scrappy:Splitting large request (15000 funds) into 15 volatility ranges
# INFO:src.scrappy:Successfully downloaded 11455 funds (category: mixed)
# INFO:src.scrappy:Splitting large request (6000 funds) into 6 volatility ranges
# INFO:src.scrappy:Successfully downloaded 3098 funds (category: mixed)
# INFO:src.scrappy:Splitting large request (8000 funds) into 8 volatility ranges
# INFO:src.scrappy:Successfully downloaded 4540 funds (category: renten)
# INFO:src.scrappy:Splitting large request (3000 funds) into 3 volatility ranges
# INFO:src.scrappy:Successfully downloaded 1218 funds (category: renten)
# INFO:src.scrappy:Splitting large request (3000 funds) into 3 volatility ranges
# INFO:src.scrappy:Successfully downloaded 1051 funds (category: esg)
# INFO:src.scrappy:Successfully downloaded 189 funds (category: esg)

# %%
s.download_timeseries(benchmarks)
s.save_timeseries('data/timeseries.csv')
# Out:
# INFO:src.scrappy:Parsing timeseries data...
# WARNING:src.scrappy:Failed to parse data for IE00B5BMR087: malformed node or string on line 1: <ast.Call object at 0x77f1cf94ed50>, use eval
# WARNING:src.scrappy:Failed to parse data for DE000A0F5UF5: malformed node or string on line 1: <ast.Call object at 0x77f1d0eca890>, use eval
# WARNING:src.scrappy:Failed to parse data for IE0005042456: malformed node or string on line 1: <ast.Call object at 0x77f1d3f56b50>, use eval
# WARNING:src.scrappy:Failed to parse data for DE0006289390: malformed node or string on line 1: <ast.Call object at 0x77f1d466bf90>, use eval
# WARNING:src.scrappy:Failed to parse data for DE0005933931: malformed node or string on line 1: <ast.Call object at 0x77f1d421c2d0>, use eval
# WARNING:src.scrappy:Failed to parse data for LU0340285161: malformed node or string on line 1: <ast.Call object at 0x77f1d4648250>, use eval

# %%
filters = {
        'initial_fee': '<=1.0', # Ausgabeaufschlag
        # 'fund_type': 'Thesaurierend',
        'is_esg': True,
        # 'sustainability_rating': ['HIGH', 'ABOVE_AVERAGE'],
        # 'sparplan_finanzen_zero': True,
        # 'finanzen_zero': True,
    }

criteria = {'performanceTimeSpanPct': 3.0, 
            'sharpeRatio': 3.0, 
            'volatility': -.0, 
            'maxDrawdown': -0.0, 
            'TER': -.0}

filtered_isins = s.filter_funds(filters).index

display(s.rank_funds(criteria=criteria, timespan='1Y', isins=filtered_isins, limit=20))

# s.filter_funds(isins=['IE00BJQRDN15'])
# Out:
# INFO:src.scrappy:After filtering initial_fee with <=1.0: 6931 funds remaining
# INFO:src.scrappy:After filtering is_esg with True: 430 funds remaining
# INFO:src.scrappy:Using pre-extracted performance data for ranking
# INFO:src.scrappy:Ranked 20 funds using criteria: {'performanceTimeSpanPct': 3.0, 'sharpeRatio': 3.0, 'volatility': -0.0, 'maxDrawdown': -0.0, 'TER': -0.0}
#                                                            name  \
# isins
# LU2489395165  Robeco QI US SDG & Climate Beta Equities - S U...
# LU2501123942  Robeco QI US SDG & Climate Beta Equities - SE ...
# LU2501124163  Robeco QI US SDG & Climate Beta Equities - SH ...
# IE00018LB0D8  Invesco S&P World Financials ESG UCITS ETF USD...
# LU2416558737  Robeco QI Global SDG & Climate Beta Equities -...
# IE0006O3TTP9  BNP Paribas Easy ECPI Global ESG Infrastructur...
# LU1256228799  GLOBALE AKTIEN - DIVIDENDE & NACHHALTIGKEIT - ...
# DE000ETFL474  Deka Oekom Euro Nachhaltigkeit UCITS ETF EUR Dis.
# LU1883320563  Amundi Funds Global Equity Responsible - R2 US...
# IE000FF2EBQ8  BNP Paribas Easy ECPI Global ESG Infrastructur...
# IE000N42HDP2  Invesco Quantitative Strategies Global Equity ...
# LU1048313891  UBS ETF MSCI Emerging Markets Socially Respons...
# IE000XIBT2R7  Invesco Quantitative Strategies Global Equity ...
# LU1883319557  Amundi Funds Global Equity Responsible - C USD...
# LU2194448853  BNP PARIBAS EASY Low Carbon 100 Eurozone PAB -...
# IE00BMP3HN93  UBS ETF MSCI United Kingdom IMI Socially Respo...
# IE00BD6PGZ66        Wellington Global Impact Fund - N GBP ACC H
# IE000E66LX20  AXA IM ACT Climate Equity UCITS ETF EUR Acc. H...
# IE0005B8WVT6  VanEck Sustainable Future of Food UCITS ETF A ...
# IE000QUCVEN9  Rize Global Sustainable Infrastructure UCITS E...
#
#               performanceTimeSpanPct  sharpeRatio  volatility  maxDrawdown  \
# isins
# LU2489395165                 26.2819       1.9879     12.9802     -10.4278
# LU2501123942                 26.7327       1.7176     13.7533      -7.7277
# LU2501124163                 25.9725       1.7597     12.9920     -10.9946
# IE00018LB0D8                 21.2889       1.8730     15.5103     -14.3968
# LU2416558737                 20.6624       1.6053     10.7597      -8.5945
# IE0006O3TTP9                 14.4685       1.8782     11.5067      -8.5070
# LU1256228799                 19.8365       1.2835     12.8056     -12.3730
# DE000ETFL474                 20.1749       0.8871     19.0904     -16.3462
# LU1883320563                 12.4762       1.3290     14.6268     -12.5016
# IE000FF2EBQ8                 14.7810       1.1246     10.2619     -10.8167
# IE000N42HDP2                  9.1395       1.3264     11.9119     -10.2288
# LU1048313891                 12.4697       1.1009     17.6535     -17.3951
# IE000XIBT2R7                 14.4932       0.9645     11.6669     -10.8524
# LU1883319557                 10.7923       1.2027     14.6358     -12.6716
# LU2194448853                 15.0616       0.9157     12.6811      -8.5445
# IE00BMP3HN93                 14.0892       0.9624     13.2842     -12.7612
# IE00BD6PGZ66                 15.1405       0.8903     15.5697     -15.5272
# IE000E66LX20                 15.2740       0.8025     14.9962     -15.0274
# IE0005B8WVT6                  8.8252       1.2022     12.8571     -10.4619
# IE000QUCVEN9                  7.8586       1.2618     11.1637     -15.2559
#
#                    TER     score
# isins
# LU2489395165  0.270000  5.966712
# LU2501123942  0.270000  5.693433
# LU2501124163  0.270000  5.685047
# IE00018LB0D8  0.180000  5.467705
# LU2416558737  0.460000  5.117825
# IE0006O3TTP9  0.310000  4.969973
# LU1256228799  0.710000  4.691862
# DE000ETFL474  0.403446  4.267264
# LU1883320563  1.280000  4.199971
# IE000FF2EBQ8  0.310000  4.138336
# IE000N42HDP2  0.250000  3.950635
# LU1048313891  0.250000  3.940786
# IE000XIBT2R7  0.300000  3.935503
# LU1883319557  2.780000  3.932383
# LU2194448853  0.130000  3.922127
# IE00BMP3HN93  0.240000  3.903290
# IE00BD6PGZ66  0.950000  3.899145
# IE000E66LX20  0.530000  3.809423
# IE0005B8WVT6  0.450000  3.786562
# IE000QUCVEN9  0.450000  3.782783

# %%
# rank by strategies
filters = {
        'initial_fee': '<=1.0', # Ausgabeaufschlag
        # 'fund_type': 'Thesaurierend',
        # 'is_esg': True,
        'sustainability_rating': ['HIGH', 'ABOVE_AVERAGE'],
        # 'sparplan_finanzen_zero': True,
        'finanzen_zero': True,
    }
filtered_isins = s.filter_funds(filters).index

display(s.rank_funds_by_strategy(timespan='1Y', isins=filtered_isins, strategy='growth', limit=20))
display(s.rank_funds_by_strategy(timespan='1Y', isins=filtered_isins, strategy='balanced'))
display(s.rank_funds_by_strategy(timespan='1Y', isins=filtered_isins, strategy='long_term'))
display(s.rank_funds_by_strategy(timespan='1Y', isins=filtered_isins, strategy='conservative'))
display(s.rank_funds_by_strategy(timespan='1Y', isins=filtered_isins, strategy='short_term'))


# finanzen.zero
invest_sparplan = {
    'growth_esg': [
        'DE000ETFL474', # Deka Oekom Euro Nachhaltigkeit UCITS ETF EUR Dis.	
        'IE00BZ02LR44',	# Xtrackers MSCI World ESG UCITS ETF 1C USD Acc.
        'DE000A0F5UG3',	# iShares Dow Jones Eurozone Sustainability Scre...	
    ],
    'growth_morningstar_sustainability': [
        'LU1829219390',	# Amundi Euro Stoxx Banks UCITS ETF EUR Acc.
        'LU1900066033', # Amundi MSCI Semiconductors ESG Screened UCITS ...
    ],
    'conservative_morningstar_sustainability': [
        'IE00B6X2VY59', # iShares EUR Corporate Bond Interest Rate Hedge...
    ],
}

invest = {
    'growth_esg': [
       'DE000ETFL474',	# Deka Oekom Euro Nachhaltigkeit UCITS ETF EUR Dis.
       'IE00BJQRDN15',	# Invesco Quantitative Strategies ESG Global Equ...
       'IE00BZ02LR44',	# Xtrackers MSCI World ESG UCITS ETF 1C USD Acc.
    ],
    'growth_morningstar_sustainability': [
        'LU1829219390',	# Amundi Euro Stoxx Banks UCITS ETF EUR Acc.
        'LU1900066033', # Amundi MSCI Semiconductors ESG Screened UCITS ...
        'IE00BKWQ0G16',	# SPDR MSCI Europe Financials UCITS ETF EUR Acc.
    ],
    'conservative_morningstar_sustainability': [
        'IE00BJK55C48',	# iShares EUR High Yield Corporate Bond ESG UCIT...
    ],
}
# Out:
# INFO:src.scrappy:After filtering initial_fee with <=1.0: 6931 funds remaining
# INFO:src.scrappy:After filtering sustainability_rating with ['HIGH', 'ABOVE_AVERAGE']: 1593 funds remaining
# INFO:src.scrappy:After filtering finanzen_zero with True: 667 funds remaining
# INFO:src.scrappy:Using ranking strategy: growth
# INFO:src.scrappy:Using pre-extracted performance data for ranking
# INFO:src.scrappy:Ranked 20 funds using criteria: {'performanceTimeSpanPct': 2.0, 'sharpeRatio': 1.0, 'volatility': -0.3, 'maxDrawdown': -0.5, 'TER': -0.7}
#                                                            name  \
# isins
# LU1829219390         Amundi Euro Stoxx Banks UCITS ETF EUR Acc.
# IE00B3Q19T94  Invesco EURO STOXX Optimised Banks UCITS ETF Acc.
# DE000A2QP372  iShares EURO STOXX Banks 30-15 UCITS ETF Acc. ...
# LU0411075376  Xtrackers LevDAX Daily Swap UCITS ETF 1C EUR Acc.
# DE0006289309  iShares EURO STOXX Banks 30-15 UCITS ETF Dis. ...
# IE00B5MTWD60  Invesco STOXX Europe 600 Optimised Banks UCITS...
# IE00BYWQWR46  VanEck Video Gaming and eSports UCITS ETF USD ...
# LU1834983477   Amundi STOXX Europe 600 Banks UCITS ETF EUR Acc.
# LU2082996112   Amundi STOXX Europe 600 Banks UCITS ETF EUR Dis.
# DE000A0F5UJ7  iShares STOXX Europe 600 Banks UCITS ETF EUR D...
# IE00BNTVVR89     HANetf AuAg ESG Gold Mining UCITS ETF USD Acc.
# IE00B6R52036          iShares Gold Producers UCITS ETF USD Acc.
# IE00BKWQ0G16     SPDR MSCI Europe Financials UCITS ETF EUR Acc.
# IE00BMW42306  iShares MSCI Europe Financials Sector UCITS ET...
# IE00BQQP9F84            VanEck Gold Miners UCITS ETF A USD Acc.
# LU2611731824      Amundi NYSE Arca Gold BUGS UCITS ETF USD Dis.
# LU0292103651  Xtrackers MSCI Europe Financials ESG Screened ...
# IE00BLR6Q544  Global X Video Games & Esports UCITS ETF USD Acc.
# FR0010655746                  Amundi IBEX 35 UCITS ETF EUR Acc.
# IE00B5MTXJ97  Invesco STOXX Europe 600 Optimised Insurance U...
#
#               performanceTimeSpanPct  sharpeRatio  volatility  maxDrawdown  \
# isins
# LU1829219390                 52.2970       1.8965     25.8676     -19.8180
# IE00B3Q19T94                 50.6686       1.9371     24.4849     -19.9042
# DE000A2QP372                 51.5029       1.9603     24.6203     -19.7958
# LU0411075376                 56.8018       1.5118     35.4293     -30.3665
# DE0006289309                 51.4754       1.9592     24.6197     -19.7962
# IE00B5MTWD60                 47.3480       1.8898     23.3395     -19.7539
# IE00BYWQWR46                 45.9860       2.7692     20.2183     -16.5386
# LU1834983477                 45.9595       1.6720     25.5503     -19.8659
# LU2082996112                 45.9556       1.6718     25.5500     -19.8663
# DE000A0F5UJ7                 46.0484       1.8689     22.9052     -19.8363
# IE00BNTVVR89                 48.2989       1.7730     32.7532     -22.3517
# IE00B6R52036                 43.2706       1.7464     30.1203     -20.7969
# IE00BKWQ0G16                 34.8938       1.7154     18.4526     -16.7151
# IE00BMW42306                 34.9247       1.6862     18.7901     -16.7755
# IE00BQQP9F84                 39.3957       1.6177     30.1660     -22.4853
# LU2611731824                 42.3289       1.4720     35.0411     -22.7194
# LU0292103651                 31.8400       1.5382     18.5937     -17.1858
# IE00BLR6Q544                 33.9842       2.2174     19.3461     -15.2670
# FR0010655746                 33.2333       1.8085     16.5850     -12.5033
# IE00B5MTXJ97                 31.2914       1.7039     16.4635     -12.5322
#
#                TER     score
# isins
# LU1829219390  0.30  3.278525
# IE00B3Q19T94  0.30  3.254636
# DE000A2QP372  0.48  3.227719
# LU0411075376  1.04  3.223301
# DE0006289309  0.52  3.216689
# IE00B5MTWD60  0.20  3.204193
# IE00BYWQWR46  0.55  3.141366
# LU1834983477  0.30  3.112129
# LU2082996112  0.30  3.112027
# DE000A0F5UJ7  0.46  3.108914
# IE00BNTVVR89  0.60  3.078189
# IE00B6R52036  0.55  2.969587
# IE00BKWQ0G16  0.18  2.897346
# IE00BMW42306  0.18  2.893848
# IE00BQQP9F84  0.53  2.892660
# LU2611731824  0.65  2.886176
# LU0292103651  0.17  2.817155
# IE00BLR6Q544  0.50  2.813035
# FR0010655746  0.30  2.796436
# IE00B5MTXJ97  0.20  2.768402
# INFO:src.scrappy:Using ranking strategy: balanced
# INFO:src.scrappy:Using pre-extracted performance data for ranking
# INFO:src.scrappy:Ranked 10 funds using criteria: {'performanceTimeSpanPct': 1.0, 'sharpeRatio': 2.0, 'volatility': -0.7, 'maxDrawdown': -1.0, 'TER': -0.8}
#                                                            name  \
# isins
# LU0041580167               DWS USD Floating Rate Notes - LD DIS
# IE00BZ048462  iShares USD Floating Rate Bond UCITS ETF USD Dis.
# LU1681040900  Amundi Floating Rate USD Corporate ESG UCITS E...
# IE00BYWQWR46  VanEck Video Gaming and eSports UCITS ETF USD ...
# IE00B3Q19T94  Invesco EURO STOXX Optimised Banks UCITS ETF Acc.
# IE00B5MTWD60  Invesco STOXX Europe 600 Optimised Banks UCITS...
# LU1829219390         Amundi Euro Stoxx Banks UCITS ETF EUR Acc.
# DE000A2QP372  iShares EURO STOXX Banks 30-15 UCITS ETF Acc. ...
# DE0006289309  iShares EURO STOXX Banks 30-15 UCITS ETF Dis. ...
# DE000A0F5UJ7  iShares STOXX Europe 600 Banks UCITS ETF EUR D...
#
#               performanceTimeSpanPct  sharpeRatio  volatility  maxDrawdown  \
# isins
# LU0041580167                 -3.3408       8.8310      0.2248      -0.1370
# IE00BZ048462                 -3.0445       6.9523      0.3189      -0.1725
# LU1681040900                 -3.0670       5.9007      0.3725      -0.3391
# IE00BYWQWR46                 45.9860       2.7692     20.2183     -16.5386
# IE00B3Q19T94                 50.6686       1.9371     24.4849     -19.9042
# IE00B5MTWD60                 47.3480       1.8898     23.3395     -19.7539
# LU1829219390                 52.2970       1.8965     25.8676     -19.8180
# DE000A2QP372                 51.5029       1.9603     24.6203     -19.7958
# DE0006289309                 51.4754       1.9592     24.6197     -19.7962
# DE000A0F5UJ7                 46.0484       1.8689     22.9052     -19.8363
#
#                 TER     score
# isins
# LU0041580167  0.353  3.696238
# IE00BZ048462  0.100  3.444541
# LU1681040900  0.180  3.239884
# IE00BYWQWR46  0.550  3.232300
# IE00B3Q19T94  0.300  3.227659
# IE00B5MTWD60  0.200  3.225046
# LU1829219390  0.300  3.214461
# DE000A2QP372  0.480  3.183662
# DE0006289309  0.520  3.171401
# DE000A0F5UJ7  0.460  3.138902
# INFO:src.scrappy:Using ranking strategy: long_term
# INFO:src.scrappy:Using pre-extracted performance data for ranking
# INFO:src.scrappy:Ranked 10 funds using criteria: {'performanceTimeSpanPct': 1.2, 'sharpeRatio': 1.5, 'volatility': -0.4, 'maxDrawdown': -0.7, 'TER': -2.0}
#                                                            name  \
# isins
# LU0041580167               DWS USD Floating Rate Notes - LD DIS
# LU1829219390         Amundi Euro Stoxx Banks UCITS ETF EUR Acc.
# IE00B3Q19T94  Invesco EURO STOXX Optimised Banks UCITS ETF Acc.
# IE00BZ048462  iShares USD Floating Rate Bond UCITS ETF USD Dis.
# IE00B5MTWD60  Invesco STOXX Europe 600 Optimised Banks UCITS...
# DE0006289309  iShares EURO STOXX Banks 30-15 UCITS ETF Dis. ...
# LU0011254512                DWS Vorsorge Geldmarkt - LC EUR ACC
# DE000A0F5UJ7  iShares STOXX Europe 600 Banks UCITS ETF EUR D...
# LU1900066033  Amundi MSCI Semiconductors ESG Screened UCITS ...
# IE00B3WJKG14  iShares S&P 500 Information Technology Sector ...
#
#               performanceTimeSpanPct  sharpeRatio  volatility  maxDrawdown  \
# isins
# LU0041580167                 13.3026      67.4673      0.2985      -0.9277
# LU1829219390                302.7330      11.0512     27.5294     -34.3151
# IE00B3Q19T94                290.3050      10.8051     27.0063     -35.4540
# IE00BZ048462                 13.9964      53.4033      0.3898      -0.7222
# IE00B5MTWD60                260.9670      10.6243     24.7045     -29.8138
# DE0006289309                297.3890      11.1435     26.8218     -34.1571
# LU0011254512                  6.8877      49.3685      0.1699      -1.7520
# DE000A0F5UJ7                261.8580      10.9415     24.0697     -27.6557
# LU1900066033                229.3410       7.4074     31.1636     -39.4010
# IE00B3WJKG14                167.4200       7.0420     25.7597     -33.6886
#
#                 TER     score
# isins
# LU0041580167  0.353  3.955267
# LU1829219390  0.300  3.886710
# IE00B3Q19T94  0.300  3.853406
# IE00BZ048462  0.100  3.842008
# IE00B5MTWD60  0.200  3.792360
# DE0006289309  0.520  3.711102
# LU0011254512  0.210  3.661981
# DE000A0F5UJ7  0.460  3.595169
# LU1900066033  0.350  3.571854
# IE00B3WJKG14  0.150  3.487419
# INFO:src.scrappy:Using ranking strategy: conservative
# INFO:src.scrappy:Using pre-extracted performance data for ranking
# INFO:src.scrappy:Ranked 10 funds using criteria: {'performanceTimeSpanPct': 0.5, 'sharpeRatio': 1.0, 'volatility': -1.5, 'maxDrawdown': -2.0, 'TER': -0.7}
#                                                            name  \
# isins
# DE000ETFL318  Deka MSCI Japan Climate Change ESG UCITS ETF M...
# LU0041580167               DWS USD Floating Rate Notes - LD DIS
# IE00BZ048462  iShares USD Floating Rate Bond UCITS ETF USD Dis.
# IE000I8KRLL9  iShares MSCI Global Semiconductors UCITS ETF U...
# IE00B5MTWD60  Invesco STOXX Europe 600 Optimised Banks UCITS...
# LU1681048630        Amundi S&P Global Luxury UCITS ETF EUR Acc.
# IE00023EZQ82  iShares Digital Entertainment and Education UC...
# IE00BNC1F287   Guinness Sustainable Energy UCITS ETF - USD Acc.
# IE000ENYES77  Amundi S&P Global Financials ESG UCITS ETF DR ...
# IE000KYX7IP4  Amundi S&P Global Financials ESG UCITS ETF DR ...
#
#               performanceTimeSpanPct  sharpeRatio  volatility  maxDrawdown  \
# isins
# DE000ETFL318                  0.6042       0.3352     22.4610     -30.2806
# LU0041580167                 -3.3408       8.8310      0.2248      -0.1370
# IE00BZ048462                 -3.0445       6.9523      0.3189      -0.1725
# IE000I8KRLL9                 -8.9379      -0.1284     32.6165     -37.8720
# IE00B5MTWD60                 47.3480       1.8898     23.3395     -19.7539
# LU1681048630                  0.8460      -0.1178     20.3221     -26.8400
# IE00023EZQ82                 25.8508       1.6738     20.1064     -21.2896
# IE00BNC1F287                 -2.1825       0.1599     19.7544     -28.1361
# IE000ENYES77                 23.4562       1.1880     17.0175     -18.4753
# IE000KYX7IP4                 23.4541       1.1878     17.0175     -18.4756
#
#                  TER     score
# isins
# DE000ETFL318  0.2509  3.271154
# LU0041580167  0.3530  3.263954
# IE00BZ048462  0.1000  3.164745
# IE000I8KRLL9  0.3500  3.161812
# IE00B5MTWD60  0.2000  3.140952
# LU1681048630  0.2500  3.138776
# IE00023EZQ82  0.4000  3.136183
# IE00BNC1F287  0.6500  3.127136
# IE000ENYES77  0.1800  3.107029
# IE000KYX7IP4  0.1800  3.107014
# INFO:src.scrappy:Using ranking strategy: short_term
# INFO:src.scrappy:Using pre-extracted performance data for ranking
# INFO:src.scrappy:Ranked 10 funds using criteria: {'performanceTimeSpanPct': 1.5, 'sharpeRatio': 1.2, 'volatility': -0.8, 'maxDrawdown': -1.0, 'TER': -0.5}
#                                                            name  \
# isins
# IE00B3Q19T94  Invesco EURO STOXX Optimised Banks UCITS ETF Acc.
# LU1829219390         Amundi Euro Stoxx Banks UCITS ETF EUR Acc.
# DE000A2QP372  iShares EURO STOXX Banks 30-15 UCITS ETF Acc. ...
# LU0411075376  Xtrackers LevDAX Daily Swap UCITS ETF 1C EUR Acc.
# IE00B5MTWD60  Invesco STOXX Europe 600 Optimised Banks UCITS...
# DE0006289309  iShares EURO STOXX Banks 30-15 UCITS ETF Dis. ...
# IE00BYWQWR46  VanEck Video Gaming and eSports UCITS ETF USD ...
# DE000A0F5UJ7  iShares STOXX Europe 600 Banks UCITS ETF EUR D...
# LU1834983477   Amundi STOXX Europe 600 Banks UCITS ETF EUR Acc.
# LU2082996112   Amundi STOXX Europe 600 Banks UCITS ETF EUR Dis.
#
#               performanceTimeSpanPct  sharpeRatio  volatility  maxDrawdown  \
# isins
# IE00B3Q19T94                 50.6686       1.9371     24.4849     -19.9042
# LU1829219390                 52.2970       1.8965     25.8676     -19.8180
# DE000A2QP372                 51.5029       1.9603     24.6203     -19.7958
# LU0411075376                 56.8018       1.5118     35.4293     -30.3665
# IE00B5MTWD60                 47.3480       1.8898     23.3395     -19.7539
# DE0006289309                 51.4754       1.9592     24.6197     -19.7962
# IE00BYWQWR46                 45.9860       2.7692     20.2183     -16.5386
# DE000A0F5UJ7                 46.0484       1.8689     22.9052     -19.8363
# LU1834983477                 45.9595       1.6720     25.5503     -19.8659
# LU2082996112                 45.9556       1.6718     25.5500     -19.8663
#
#                TER     score
# isins
# IE00B3Q19T94  0.30  3.145655
# LU1829219390  0.30  3.141601
# DE000A2QP372  0.48  3.124486
# LU0411075376  1.04  3.124233
# IE00B5MTWD60  0.20  3.118468
# DE0006289309  0.52  3.116552
# IE00BYWQWR46  0.55  3.102173
# DE000A0F5UJ7  0.46  3.055833
# LU1834983477  0.30  3.013073
# LU2082996112  0.30  3.012998

# %%
summary_cols = ['name', 'fund_type', 'initial_fee', 'TER', 'type',
                'investment_focus', 'min_initial_investment', 'min_followup_investment',
                'finanzen_zero', 'sparplan_finanzen_zero']

invest_sparplan_isins = [isin for topic in invest_sparplan.values() for isin in topic]
invest_isins = [isin for topic in invest.values() for isin in topic]

invest_all = list(set(invest_sparplan_isins + invest_isins))

display(s.filter_funds(isins=invest_all)[summary_cols])

s.download_timeseries(invest_all)
s.save_timeseries('data/timeseries.csv')

s.plot_correlations(invest_all)
# Out:
# /home/igor/miniconda3/envs/scrappy/lib/python3.12/site-packages/seaborn/matrix.py:1124: UserWarning: ``square=True`` ignored in clustermap
#   warnings.warn(msg)
#               IE00B6X2VY59  DE000ETFL474  DE000A0F5UG3  LU1829219390  \
# IE00B6X2VY59      1.000000      0.531855      0.523065      0.585122
# DE000ETFL474      0.531855      1.000000      0.983607      0.902587
# DE000A0F5UG3      0.523065      0.983607      1.000000      0.868693
# LU1829219390      0.585122      0.902587      0.868693      1.000000
# IE00BJK55C48      0.856716      0.683410      0.685393      0.642820
# IE00BZ02LR44      0.445034      0.834819      0.843874      0.705231
# IE00BZ048462      0.714651      0.312994      0.311871      0.375284
# LU1681040900      0.775791      0.250030      0.241826      0.334633
# IE00BJQRDN15      0.501502      0.845971      0.852606      0.736553
# LU1900066033      0.296210      0.456437      0.459193      0.310222
# IE00BKWQ0G16      0.568139      0.947821      0.927735      0.961732
#
#               IE00BJK55C48  IE00BZ02LR44  IE00BZ048462  LU1681040900  \
# IE00B6X2VY59      0.856716      0.445034      0.714651      0.775791
# DE000ETFL474      0.683410      0.834819      0.312994      0.250030
# DE000A0F5UG3      0.685393      0.843874      0.311871      0.241826
# LU1829219390      0.642820      0.705231      0.375284      0.334633
# IE00BJK55C48      1.000000      0.657144      0.697715      0.701508
# IE00BZ02LR44      0.657144      1.000000      0.271680      0.233360
# IE00BZ048462      0.697715      0.271680      1.000000      0.906952
# LU1681040900      0.701508      0.233360      0.906952      1.000000
# IE00BJQRDN15      0.685210      0.972298      0.317765      0.290047
# LU1900066033      0.379332      0.663422      0.200066      0.217869
# IE00BKWQ0G16      0.681809      0.776764      0.355980      0.295389
#
#               IE00BJQRDN15  LU1900066033  IE00BKWQ0G16
# IE00B6X2VY59      0.501502      0.296210      0.568139
# DE000ETFL474      0.845971      0.456437      0.947821
# DE000A0F5UG3      0.852606      0.459193      0.927735
# LU1829219390      0.736553      0.310222      0.961732
# IE00BJK55C48      0.685210      0.379332      0.681809
# IE00BZ02LR44      0.972298      0.663422      0.776764
# IE00BZ048462      0.317765      0.200066      0.355980
# LU1681040900      0.290047      0.217869      0.295389
# IE00BJQRDN15      1.000000      0.639906      0.800257
# LU1900066033      0.639906      1.000000      0.338449
# IE00BKWQ0G16      0.800257      0.338449      1.000000

# %%
# favs = ['IE00BCRY6557', # iShares EUR Ultrashort Bond UCITS ETF Dis.
#         'IE000NBRE3P7', # iShares EUR Ultrashort Bond ESG UCITS ETF EUR Acc.
#         'LU1109942653', # Xtrackers II EUR High Yield Corporate Bond UCITS ETF 1D Dis.
#         'LU1109943388', # Xtrackers II EUR High Yield Corporate Bond UCITS ETF 1C Acc.
#         'DE000ETFL474', # Deka Oekom Euro Nachhaltigkeit UCITS ETF EUR Dis.
#         'LU0274211480', # Xtrackers DAX UCITS ETF 1C EUR Acc.
#         'DE000A0F5UF5', # iShares NASDAQ-100 UCITS ETF USD Dis. (DE)
#         'IE00B53SZB19', # iShares NASDAQ-100 UCITS ETF USD Acc.
#         'IE00BZ02LR44', # Xtrackers MSCI World ESG UCITS ETF 1C USD Acc.	
#         'IE00BM67HX07', # Xtrackers S&P 500 UCITS ETF 2C GBP Acc. Hedged
#     ]

# invest_sparplan = ['IE00BCRY6557', 'IE000NBRE3P7', 'LU1109942653', 'LU1109943388', 'DE000ETFL474', 'IE00B53SZB19']
# invest = ['IE000UI6SLV6']


# s.download_timeseries(favs)
# s.save_timeseries('data/timeseries.csv')

display(s.filter_funds(isins=favs))

s.plot_correlations(favs)

s.plot_timeseries(invest+benchmarks, transform='yesterday', name_column='name')
# Out:
#                                                            name type  \
# isin
# IE000NBRE3P7  iShares EUR Ultrashort Bond ESG UCITS ETF EUR ...  ETF
# IE00BFY0GT14                 SPDR MSCI World UCITS ETF USD Acc.  ETF
# LU0274211480                Xtrackers DAX UCITS ETF 1C EUR Acc.  ETF
# IE00BM67HX07     Xtrackers S&P 500 UCITS ETF 2C GBP Acc. Hedged  ETF
# IE00B53SZB19              iShares NASDAQ-100 UCITS ETF USD Acc.  ETF
# DE000A0F5UF5         iShares NASDAQ-100 UCITS ETF USD Dis. (DE)  ETF
# LU1109943388  Xtrackers II EUR High Yield Corporate Bond UCI...  ETF
# LU1109942653  Xtrackers II EUR High Yield Corporate Bond UCI...  ETF
# IE00BCRY6557         iShares EUR Ultrashort Bond UCITS ETF Dis.  ETF
# DE000ETFL474  Deka Oekom Euro Nachhaltigkeit UCITS ETF EUR Dis.  ETF
#
#                              investment_focus         region     issuer  \
# isin
# IE000NBRE3P7              Geldmarkt-Fonds EUR  International  BlackRock
# IE00BFY0GT14             Aktien International  International       SSGA
# LU0274211480               Aktien Deutschland       Euroland        DWS
# IE00BM67HX07                       Aktien USA    Nordamerika        DWS
# IE00B53SZB19                       Aktien USA    Nordamerika  BlackRock
# DE000A0F5UF5                       Aktien USA    Nordamerika  BlackRock
# LU1109943388  Renten International High Yield  International        DWS
# LU1109942653                       Renten EUR  International        DWS
# IE00BCRY6557                    Renten Europa  International  BlackRock
# DE000ETFL474     Aktien Ethik, Nachhaltigkeit       Euroland       Deka
#
#                                                       benchmark      country  \
# isin
# IE000NBRE3P7  IBOXX MSCI ESG EUR LIQUID INVESTMENT GRADE ULT...       Irland
# IE00BFY0GT14                                         MSCI World       Irland
# LU0274211480                                                DAX    Luxemburg
# IE00BM67HX07                                            S&P 500       Irland
# IE00B53SZB19                                         NASDAQ 100       Irland
# DE000A0F5UF5                                         NASDAQ 100  Deutschland
# LU1109943388           MARKIT IBOXX EUR LIQUID HIGH YIELD INDEX    Luxemburg
# LU1109942653           MARKIT IBOXX EUR LIQUID HIGH YIELD INDEX    Luxemburg
# IE00BCRY6557  MARKIT IBOXX EUR LIQUID INVESTMENT GRADE ULTRA...       Irland
# DE000ETFL474              SOLACTIVE EURO PRIME ESG (PREISINDEX)  Deutschland
#
#              currency        volume      fund_type  initial_fee       TER  \
# isin
# IE000NBRE3P7      EUR  6.840778e+08  Thesaurierend          0.0  0.090000
# IE00BFY0GT14      USD  1.264668e+10  Thesaurierend          0.0  0.120000
# LU0274211480      EUR  6.373720e+09  Thesaurierend          0.0  0.092000
# IE00BM67HX07      GBP  1.132160e+09  Thesaurierend          0.0  0.091000
# IE00B53SZB19      USD  1.867861e+10  Thesaurierend          0.0  0.330000
# DE000A0F5UF5      USD  4.739667e+09   Ausschüttend          0.0  0.310000
# LU1109943388      EUR  1.614104e+09  Thesaurierend          0.0  0.233000
# LU1109942653      EUR  1.614104e+09   Ausschüttend          0.0  0.233000
# IE00BCRY6557      EUR  4.423304e+09   Ausschüttend          0.0  0.090000
# DE000ETFL474      EUR  3.427688e+08   Ausschüttend          0.0  0.403446
#
#               morningstar  morningstar_3y  morningstar_5y feri  risk_class  \
# isin
# IE000NBRE3P7          NaN             NaN             NaN  (B)         1.0
# IE00BFY0GT14          5.0             4.0             5.0  (B)         4.0
# LU0274211480          5.0             5.0             5.0  (A)         4.0
# IE00BM67HX07          NaN             NaN             NaN  (E)         4.0
# IE00B53SZB19          5.0             4.0             5.0  (B)         4.0
# DE000A0F5UF5          5.0             4.0             5.0  (B)         4.0
# LU1109943388          4.0             4.0             4.0  (B)         1.0
# LU1109942653          3.0             4.0             3.0  (B)         1.0
# IE00BCRY6557          4.0             3.0             3.0  (C)         1.0
# DE000ETFL474          5.0             5.0             5.0  (A)         4.0
#
#                                                     performance  \
# isin
# IE000NBRE3P7  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...
# IE00BFY0GT14  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...
# LU0274211480  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...
# IE00BM67HX07  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...
# IE00B53SZB19  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...
# DE000A0F5UF5  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...
# LU1109943388  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...
# LU1109942653  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...
# IE00BCRY6557  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...
# DE000ETFL474  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...
#
#                                                            risk     wkn  \
# isin
# IE000NBRE3P7  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...  A3EEYV
# IE00BFY0GT14  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...  A2N6CW
# LU0274211480  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...  DBX1DA
# IE00BM67HX07  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...  A113FQ
# IE00B53SZB19  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...  A0YEDL
# DE000A0F5UF5  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...  A0F5UF
# LU1109943388  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...  DBX0PS
# LU1109942653  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...  DBX0PR
# IE00BCRY6557  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...  A1W375
# DE000ETFL474  [{'timeSpan': '1M', 'nameTimeSpan': '1 Monat',...  ETFL47
#
#               all_in_fee currency_fee  depot_bank_fee  switching_fee  \
# isin
# IE000NBRE3P7         NaN          NaN             NaN            NaN
# IE00BFY0GT14         NaN          NaN             NaN            NaN
# LU0274211480        0.09          NaN             NaN            1.0
# IE00BM67HX07        0.09          NaN             NaN            3.0
# IE00B53SZB19         NaN          NaN             NaN            NaN
# DE000A0F5UF5         NaN          NaN             NaN            NaN
# LU1109943388        0.20          NaN             NaN            1.0
# LU1109942653        0.20          NaN             NaN            1.0
# IE00BCRY6557         NaN          NaN             NaN            NaN
# DE000ETFL474         NaN          NaN          0.0238            NaN
#
#               distribution_fee  redemption_fee sustainability_rating  \
# isin
# IE000NBRE3P7               0.0             0.0               AVERAGE
# IE00BFY0GT14               NaN             0.0         BELOW_AVERAGE
# LU0274211480               0.0             0.0               AVERAGE
# IE00BM67HX07               0.0             0.0               AVERAGE
# IE00B53SZB19               0.0             0.0               AVERAGE
# DE000A0F5UF5               0.0             0.0               AVERAGE
# LU1109943388               0.0             0.0                   NaN
# LU1109942653               0.0             0.0                   NaN
# IE00BCRY6557               0.0             0.0         BELOW_AVERAGE
# DE000ETFL474               NaN             0.0                  HIGH
#
#               min_initial_investment  min_followup_investment  is_esg  \
# isin
# IE000NBRE3P7                     NaN                      NaN   False
# IE00BFY0GT14                     NaN                      NaN   False
# LU0274211480                     NaN                      NaN   False
# IE00BM67HX07                     NaN                      NaN   False
# IE00B53SZB19                     NaN                      NaN   False
# DE000A0F5UF5                     NaN                      NaN   False
# LU1109943388                     NaN                      NaN   False
# LU1109942653                     NaN                      NaN   False
# IE00BCRY6557                     NaN                      NaN   False
# DE000ETFL474                     NaN                      NaN    True
#
#               is_renten  is_benchmark sparplan_finanzen_zero  finanzen_zero
# isin
# IE000NBRE3P7      False         False                   True           True
# IE00BFY0GT14      False         False                   True           True
# LU0274211480      False         False                   True           True
# IE00BM67HX07      False         False                   True           True
# IE00B53SZB19      False         False                   True           True
# DE000A0F5UF5      False         False                   True           True
# LU1109943388       True         False                   True           True
# LU1109942653       True         False                   True           True
# IE00BCRY6557       True         False                   True           True
# DE000ETFL474      False         False                   True           True
# WARNING:src.scrappy:Not in timeseries: ['IE000UI6SLV6']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File index.pyx:609, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1748476800000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:577, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File index.pyx:611, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2025-05-29 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/indexes/datetimes.py:630, in DatetimeIndex.get_loc(self, key)
#     629 try:
# --> 630     return Index.get_loc(self, key)
#     631 except KeyError as err:
#
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: Timestamp('2025-05-29 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 24
#      20 display(s.filter_funds(isins=favs))
#      22 s.plot_correlations(favs)
# ---> 24 s.plot_timeseries(invest+benchmarks, transform='yesterday', name_column='name')
#
# File ~/git/scrappy/src/scrappy.py:1405, in Scrappy.plot_timeseries(self, *args, **kwargs)
#    1403 def plot_timeseries(self, *args, **kwargs):
#    1404     """Create interactive timeseries visualization of fund prices."""
# -> 1405     return self.visualizer.plot_timeseries(*args, **kwargs)
#
# File ~/git/scrappy/src/scrappy.py:1109, in FundsVisualizer.plot_timeseries(self, columns, transform, legend, name_column, title)
#    1106     else:
#    1107         transform_func = transform
# -> 1109     ts = ts.interpolate('time').apply(transform_func, result_type=None)
#    1111 # Convert to long format for plotly
#    1112 ts_long = ts.reset_index().melt(id_vars=ts.index.name,
#    1113                                var_name='Fund', value_name='Value').dropna()
#
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File ~/git/scrappy/src/scrappy.py:1105, in FundsVisualizer.plot_timeseries.<locals>.<lambda>(s)
#    1102     if isinstance(date, str):
#    1103         date = pd.to_datetime(date)
# -> 1105     transform_func = lambda s: s / s.loc[date] * 100
#    1106 else:
#    1107     transform_func = transform
#
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/indexes/datetimes.py:632, in DatetimeIndex.get_loc(self, key)
#     630     return Index.get_loc(self, key)
#     631 except KeyError as err:
# --> 632     raise KeyError(orig_key) from err
#
# KeyError: Timestamp('2025-05-29 00:00:00')

# %%
# search by regex
esg_funds = s.search_funds_by_pattern('ESG|Sustainable|Green', column='name')
# esg_funds.head()

# s.filter_funds(benchmarks)

# s.extract_performance()

# s.filter_top_performers(by='sharpeRatio', timespan='1Y', limit=10)

# s.plot_timeseries(benchmarks, transform='2020-01-01')

# s.plot_correlations(benchmarks)

s.plot_risk_return(benchmarks)

# s.plot_benchmark_comparison(benchmarks)

# s.plot_benchmark_comparison(benchmarks, plot_difference=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_23158/3848830649.py in ?()
#      11 # s.plot_timeseries(benchmarks, transform='2020-01-01')
#      12
#      13 # s.plot_correlations(benchmarks)
#      14
# ---> 15 s.plot_risk_return(benchmarks)
#      16
#      17 # s.plot_benchmark_comparison(benchmarks)
#      18
#
# ~/git/scrappy/src/scrappy.py in ?(self, *args, **kwargs)
#    1037     def plot_risk_return(self, *args, **kwargs):
#    1038         """Create risk-return scatter plot for fund analysis."""
# -> 1039         return self.visualizer.plot_risk_return(*args, **kwargs)
#
# ~/git/scrappy/src/scrappy.py in ?(self, timespan, isins, benchmark_isins, title)
#     789                                isins: Optional[List[str]] = None,
#     790                                benchmark_isins: Optional[List[str]] = None,
#     791                                title: str = "Risk vs Return Analysis"):
#     792         """Create risk-return scatter plot."""
# --> 793         risk_return_data = self.analyzer.calculate_risk_return_metrics(timespan, isins)
#     794
#     795         if risk_return_data.empty:
#     796             logger.warning(f"No risk-return data available for timespan {timespan}.")
#
# ~/git/scrappy/src/scrappy.py in ?(self, timespan, isins)
#     688                 risk_return_data.at[isin, 'name'] = funds_df.at[isin, 'name']
#     689             else:
#     690                 risk_return_data.at[isin, 'name'] = isin
#     691
# --> 692         return risk_return_data.dropna(subset=['return', 'volatility'])
#
# ~/miniconda3/envs/scrappy/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['return', 'volatility']

# %%
s.save_funds_overview('data/funds_overview_test.csv')
s.save_performance('data/performance_test.csv')
s.save_timeseries('data/timeseries_test.csv')

# %%
s.ts.interpolate('time')
# Out:
#             AT0000497409  AT0000497417  AT0000604384  AT0000613286  \
# x
# 1938-02-03           NaN           NaN           NaN           NaN
# 1938-02-14           NaN           NaN           NaN           NaN
# 1938-02-28           NaN           NaN           NaN           NaN
# 1938-03-03           NaN           NaN           NaN           NaN
# 1938-03-11           NaN           NaN           NaN           NaN
# ...                  ...           ...           ...           ...
# 2025-05-19        131.63        131.62        156.05         15.56
# 2025-05-20        131.63        131.62        156.05         15.56
# 2025-05-21        131.63        131.62        156.05         15.56
# 2025-05-22        131.63        131.62        156.05         15.56
# 2025-05-23        131.63        131.62        156.05         15.56
#
#             AT0000619358  AT0000631924  AT0000639430  AT0000642343  \
# x
# 1938-02-03           NaN           NaN           NaN           NaN
# 1938-02-14           NaN           NaN           NaN           NaN
# 1938-02-28           NaN           NaN           NaN           NaN
# 1938-03-03           NaN           NaN           NaN           NaN
# 1938-03-11           NaN           NaN           NaN           NaN
# ...                  ...           ...           ...           ...
# 2025-05-19         17.52        181.17        181.21        206.26
# 2025-05-20         17.52        181.17        181.21        206.26
# 2025-05-21         17.52        181.17        181.21        206.26
# 2025-05-22         17.52        181.17        181.21        206.26
# 2025-05-23         17.52        181.17        181.21        206.26
#
#             AT0000645973  AT0000646799  ...  LU2355687216  LU2363199626  \
# x                                       ...
# 1938-02-03           NaN           NaN  ...           NaN           NaN
# 1938-02-14           NaN           NaN  ...           NaN           NaN
# 1938-02-28           NaN           NaN  ...           NaN           NaN
# 1938-03-03           NaN           NaN  ...           NaN           NaN
# 1938-03-11           NaN           NaN  ...           NaN           NaN
# ...                  ...           ...  ...           ...           ...
# 2025-05-19        176.03        535.61  ...         92.57         97.19
# 2025-05-20        176.03        535.61  ...         92.57         97.19
# 2025-05-21        176.03        535.61  ...         92.57         97.19
# 2025-05-22        176.03        535.61  ...         92.57         97.19
# 2025-05-23        176.03        535.61  ...         92.57         97.19
#
#             LU2363200226  LU2363200499  LU2368674631  LU2368889163  \
# x
# 1938-02-03           NaN           NaN           NaN           NaN
# 1938-02-14           NaN           NaN           NaN           NaN
# 1938-02-28           NaN           NaN           NaN           NaN
# 1938-03-03           NaN           NaN           NaN           NaN
# 1938-03-11           NaN           NaN           NaN           NaN
# ...                  ...           ...           ...           ...
# 2025-05-19         97.19         97.34         15.52         91.57
# 2025-05-20         97.19         97.34         15.52         91.57
# 2025-05-21         97.19         97.34         15.52         91.57
# 2025-05-22         97.19         97.34         15.52         91.57
# 2025-05-23         97.19         97.34         15.52         91.57
#
#             NL0000289783  NL0009690254  NL0010273801  NL0010408704
# x
# 1938-02-03           NaN           NaN           NaN           NaN
# 1938-02-14           NaN           NaN           NaN           NaN
# 1938-02-28           NaN           NaN           NaN           NaN
# 1938-03-03          0.69           NaN           NaN           NaN
# 1938-03-11          0.69           NaN           NaN           NaN
# ...                  ...           ...           ...           ...
# 2025-05-19        144.69          17.3         25.45         35.82
# 2025-05-20        144.69          17.3         25.45         35.82
# 2025-05-21        144.69          17.3         25.45         35.82
# 2025-05-22        144.69          17.3         25.45         35.82
# 2025-05-23        144.69          17.3         25.45         35.82
#
# [11217 rows x 1627 columns]
