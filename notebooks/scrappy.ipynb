# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from src.scrappy import Scrappy

pd.set_option('future.no_silent_downcasting', True)

s = Scrappy(
        funds_overview_path='data/funds_overview.csv',
        performance_path='data/performance.csv',
        timeseries_path='data/timeseries.csv'
    )

benchmarks = ['IE00B5BMR087', 'DE000A0F5UF5', 'IE0005042456', 'DE0006289390', 'DE0005933931', 'LU0340285161']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# INFO:src.scrappy:Loaded funds_overview data from data/funds_overview.csv
# INFO:src.scrappy:Loaded performance data from data/performance.csv
# INFO:src.scrappy:Loaded timeseries data from data/timeseries.csv

# %%
renten_eu = [5531,5674,5676,5673,5647,5646,5620,5576,5670,5677]
renten_all = [5634,5532,5645,5620,5670,5560,5646,5647,5531,5672,
              5673,5674,5676,5677,5648,5643,5534,5644,5570,5678,
              5679,5680,5535,5681,5581,5625,5651,5654,5622,5652,
              5557,5684,5685,5653,5558]
s.download_funds_overview(benchmark=True)
s.download_funds_overview(limit=2000, etf=False)
s.download_funds_overview(limit=1000, etf=True)
s.download_funds_overview(limit=17000, filter_ids=renten_all, etf=False)
s.download_funds_overview(limit=2000, filter_ids=renten_all, etf=True)

s.extract_performance()

s.save_funds_overview('data/funds_overview.csv')
s.save_performance('data/performance.csv')
# Out:
# INFO:src.scrappy:Successfully downloaded 55 funds
# INFO:src.scrappy:Successfully downloaded 1940 funds
# INFO:src.scrappy:Successfully downloaded 201 funds
# INFO:src.scrappy:Successfully downloaded 2000 funds
# INFO:src.scrappy:Successfully downloaded 1001 funds

# %%
s.download_timeseries(benchmarks)
s.save_timeseries('data/timeseries.csv')
# Out:
# INFO:src.scrappy:Parsing timeseries data...
# WARNING:src.scrappy:Failed to parse data for IE00B5BMR087: malformed node or string on line 1: <ast.Call object at 0x7ddc91a0f710>, use eval
# WARNING:src.scrappy:Failed to parse data for DE000A0F5UF5: malformed node or string on line 1: <ast.Call object at 0x7ddc92651350>, use eval
# WARNING:src.scrappy:Failed to parse data for IE0005042456: malformed node or string on line 1: <ast.Call object at 0x7ddc937655d0>, use eval
# WARNING:src.scrappy:Failed to parse data for DE0006289390: malformed node or string on line 1: <ast.Call object at 0x7ddc91eb3ed0>, use eval
# WARNING:src.scrappy:Failed to parse data for DE0005933931: malformed node or string on line 1: <ast.Call object at 0x7ddc8d5c3310>, use eval
# WARNING:src.scrappy:Failed to parse data for LU0340285161: malformed node or string on line 1: <ast.Call object at 0x7ddc902be150>, use eval

# %%
filters = {
        'initial_fee': '<=1.0', # Ausgabeaufschlag
        'fund_type': 'Thesaurierend',
        'sparplan_finanzen_zero': True,
    }

criteria = {'performanceTimeSpanPct': 0.0, 
            'sharpeRatio': 2.0, 
            'volatility': -0.0, 
            'maxDrawdown': -0.0, 
            'TER': -0.0}

filtered_isins = s.filter_funds(filters)[['name', 'initial_fee', 'sparplan_finanzen_zero']].index

s.rank_funds(criteria=criteria, timespan='5Y', isins=filtered_isins, limit=20)
# Out:
# INFO:src.scrappy:After filtering initial_fee with <=1.0: 2050 funds remaining
# INFO:src.scrappy:After filtering fund_type with Thesaurierend: 1338 funds remaining
# INFO:src.scrappy:After filtering sparplan_finanzen_zero with True: 240 funds remaining
# INFO:src.scrappy:Using pre-extracted performance data for ranking
# INFO:src.scrappy:Ranked 20 funds using criteria: ['performanceTimeSpanPct', 'sharpeRatio', 'volatility', 'maxDrawdown', 'TER']
#                                                            name  \
# isins
# IE00BDFGJ627  iShares USD Floating Rate Bond UCITS ETF USD Acc.
# LU1681040900  Amundi Floating Rate USD Corporate ESG UCITS E...
# LU1681041114  Amundi Floating Rate Euro Corporate ESG UCITS ...
# LU0613540268  Xtrackers II Italy Government Bond 0-1 Swap UC...
# LU1681041031  Amundi Floating Rate USD Corporate ESG UCITS E...
# IE00BZ173W74  iShares USD Corporate Bond Interest Rate Hedge...
# IE00BF3N7094  iShares Euro High Yield Corporate Bond UCITS E...
# ...

# %%
# rank by strategies
filters = {
        'initial_fee': '<=1.0', # Ausgabeaufschlag
        'fund_type': 'Thesaurierend',
        'sparplan_finanzen_zero': True,
    }
filtered_isins = s.filter_funds(filters)[['name', 'initial_fee', 'sparplan_finanzen_zero']].index

print("conservative")
display(s.rank_funds_by_strategy(timespan='5Y', isins=filtered_isins, strategy='conservative'))
print("growth")
display(s.rank_funds_by_strategy(timespan='5Y', isins=filtered_isins, strategy='growth'))
print("balanced")
display(s.rank_funds_by_strategy(timespan='5Y', isins=filtered_isins, strategy='balanced'))
print("long_term")
display(s.rank_funds_by_strategy(timespan='5Y', isins=filtered_isins, strategy='long_term'))
print("short_term")
display(s.rank_funds_by_strategy(timespan='1Y', isins=filtered_isins, strategy='short_term'))
# Out:
# INFO:src.scrappy:After filtering initial_fee with <=1.0: 2050 funds remaining
# INFO:src.scrappy:After filtering fund_type with Thesaurierend: 1338 funds remaining
# INFO:src.scrappy:After filtering sparplan_finanzen_zero with True: 240 funds remaining
# INFO:src.scrappy:Using conservative strategy for ranking
# INFO:src.scrappy:Using pre-extracted performance data for ranking
# INFO:src.scrappy:Ranked 10 funds using criteria: ['performanceTimeSpanPct', 'sharpeRatio', 'volatility', 'maxDrawdown', 'TER']
# conservative
#                                                            name  \
# isins
# IE00BDFGJ627  iShares USD Floating Rate Bond UCITS ETF USD Acc.
# LU1287023268  Amundi Euro Government Bond 15+ years UCITS ET...
# IE00BH04GW44                Vanguard UK Gilt UCITS ETF GBP Acc.
# IE00BZ171348  iShares Global AAA-AA Government Bond UCITS ET...
# LU1920015440  Xtrackers II USD Emerging Markets Bond UCITS E...
# LU0950674332  UBS ETF MSCI World Socially Responsible UCITS ...
# ...

# %%
favs = ['IE00BCRY6557', # iShares EUR Ultrashort Bond UCITS ETF Dis.
        'IE000NBRE3P7', # iShares EUR Ultrashort Bond ESG UCITS ETF EUR Acc.
        'LU1109942653', # Xtrackers II EUR High Yield Corporate Bond UCITS ETF 1D Dis.
        'LU1109943388', # Xtrackers II EUR High Yield Corporate Bond UCITS ETF 1C Acc.
        'DE000ETFL474', # Deka Oekom Euro Nachhaltigkeit UCITS ETF EUR Dis.
        'LU0274211480', # Xtrackers DAX UCITS ETF 1C EUR Acc.
        'DE000A0F5UF5', # iShares NASDAQ-100 UCITS ETF USD Dis. (DE)
        'IE00B53SZB19', # iShares NASDAQ-100 UCITS ETF USD Acc.
        'IE00BFY0GT14', # SPDR MSCI World UCITS ETF USD Acc.
        'IE00BM67HX07', # Xtrackers S&P 500 UCITS ETF 2C GBP Acc. Hedged
    ]

invest_sparplan = ['IE00BCRY6557', 'IE000NBRE3P7', 'LU1109942653', 'LU1109943388', 'DE000ETFL474', 'IE00B53SZB19']
invest = ['IE000UI6SLV6']


# s.download_timeseries(favs)
# s.save_timeseries('data/timeseries.csv')

display(s.filter_funds(isins=favs))

s.plot_correlations(favs)

s.plot_timeseries(invest+benchmarks, transform='yesterday', name_column='name')
# Out:
# WARNING:src.scrappy:ISINs not found: {'IE000NBRE3P7'}
#                                                            name type  \
# isin
# LU0274211480                Xtrackers DAX UCITS ETF 1C EUR Acc.  ETF
# IE00BM67HX07     Xtrackers S&P 500 UCITS ETF 2C GBP Acc. Hedged  ETF
# IE00B53SZB19              iShares NASDAQ-100 UCITS ETF USD Acc.  ETF
# DE000A0F5UF5         iShares NASDAQ-100 UCITS ETF USD Dis. (DE)  ETF
# IE00BFY0GT14                 SPDR MSCI World UCITS ETF USD Acc.  ETF
# DE000ETFL474  Deka Oekom Euro Nachhaltigkeit UCITS ETF EUR Dis.  ETF
# LU1109943388  Xtrackers II EUR High Yield Corporate Bond UCI...  ETF
# LU1109942653  Xtrackers II EUR High Yield Corporate Bond UCI...  ETF
# IE00BCRY6557         iShares EUR Ultrashort Bond UCITS ETF Dis.  ETF
#
#                              investment_focus         region     issuer  \
# isin
# LU0274211480               Aktien Deutschland       Euroland        DWS
# ...

# %%
# search by regex
esg_funds = s.search_funds_by_pattern('ESG|Sustainable|Green', column='name')
# esg_funds.head()

# s.filter_funds(benchmarks)

# s.extract_performance()

# s.filter_top_performers(by='sharpeRatio', timespan='1Y', limit=10)

# s.plot_timeseries(benchmarks, transform='2020-01-01')

# s.plot_correlations(benchmarks)

s.plot_risk_return(benchmarks)

# s.plot_benchmark_comparison(benchmarks)

# s.plot_benchmark_comparison(benchmarks, plot_difference=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_23158/3848830649.py in ?()
#      11 # s.plot_timeseries(benchmarks, transform='2020-01-01')
#      12
#      13 # s.plot_correlations(benchmarks)
#      14
# ---> 15 s.plot_risk_return(benchmarks)
#      16
#      17 # s.plot_benchmark_comparison(benchmarks)
#      18
#
# ~/git/scrappy/src/scrappy.py in ?(self, *args, **kwargs)
#    1037     def plot_risk_return(self, *args, **kwargs):
#    1038         """Create risk-return scatter plot for fund analysis."""
# -> 1039         return self.visualizer.plot_risk_return(*args, **kwargs)
#
# ~/git/scrappy/src/scrappy.py in ?(self, timespan, isins, benchmark_isins, title)
#     789                                isins: Optional[List[str]] = None,
#     790                                benchmark_isins: Optional[List[str]] = None,
# ...

# %%
s.save_funds_overview('data/funds_overview_test.csv')
s.save_performance('data/performance_test.csv')
s.save_timeseries('data/timeseries_test.csv')

# %%
s.ts.interpolate('time')
# Out:
#             AT0000497409  AT0000497417  AT0000604384  AT0000613286  \
# x
# 1938-02-03           NaN           NaN           NaN           NaN
# 1938-02-14           NaN           NaN           NaN           NaN
# 1938-02-28           NaN           NaN           NaN           NaN
# 1938-03-03           NaN           NaN           NaN           NaN
# 1938-03-11           NaN           NaN           NaN           NaN
# ...                  ...           ...           ...           ...
# 2025-05-19        131.63        131.62        156.05         15.56
# 2025-05-20        131.63        131.62        156.05         15.56
# 2025-05-21        131.63        131.62        156.05         15.56
# 2025-05-22        131.63        131.62        156.05         15.56
# 2025-05-23        131.63        131.62        156.05         15.56
#
#             AT0000619358  AT0000631924  AT0000639430  AT0000642343  \
# x
# 1938-02-03           NaN           NaN           NaN           NaN
# ...
